# %%
## for m1 chip; https://pytorch.org/get-started/locally/
## see github issue; https://github.com/UKPLab/sentence-transformers/issues/1736

import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.6332, 0.1310, 0.6753],
#         [0.9108, 0.8022, 0.8582],
#         [0.9889, 0.3496, 0.3971],
#         [0.8231, 0.8841, 0.6034],
#         [0.3201, 0.3174, 0.1249]])

# %% [markdown]
# ## -- Step 1 -  Import necessary libraries ---

# %%
import pandas as pd
import requests
import hopsworks
import exclude.key

# %%
from sentence_transformers import SentenceTransformer

# %% [markdown]
# ## -- Step 2 - Define Hopsworks and Google API keys and connect to Hopsworks ---

# %%
# Hopsworks and Google API keys
HOPSWORKS_API_KEY = exclude.key.HOPSWORKS_API_KEY
FEATURE_GROUP_NAME = "bars_near_london_bridge"
FEATURE_GROUP_EMBEDDING_NAME = "venue_description_embeddings"
FEATURE_GROUP_EMBEDDING_VERSION = 2
FEATURE_GROUP_VERSION = 3
GOOGLE_API_KEY = exclude.key.GOOGLE_API_KEY

# Connect to Hopsworks
project = hopsworks.login(api_key_value=HOPSWORKS_API_KEY)
fs = project.get_feature_store()
# Out:
# Connection closed.
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/25749
# Connected. Call `.close()` to terminate connection gracefully.

# %% [markdown]
# ### Step 3: Retrieve Feature Group

# %%
def get_or_create_feature_group():
    try:
        fg = fs.get_feature_group(name=FEATURE_GROUP_NAME, version=FEATURE_GROUP_VERSION)
    except:
        fg = fs.create_feature_group(
            name=FEATURE_GROUP_NAME,
            version=FEATURE_GROUP_VERSION,
            description="Foot traffic data for bars near London Bridge",
            primary_key=['venue_name', 'day', 'hour'],
            event_time='last_updated',
            online_enabled=True
        )
    return fg

feature_group_venues = get_or_create_feature_group()
df = feature_group_venues.read()

# Display the DataFrame
print(df)
# Out:
# 2024-06-12 13:53:21,674 WARNING: DeprecationWarning: DatetimeTZBlock is deprecated and will be removed in a future version. Use public APIs instead.
#
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (4.61s)
#                             venue_name  \
# 0                           Nine Lives
# 1      The Hung Drawn & Quartered, EC3
# 2                El Vino London Bridge
# 3               The Bridge Tap, London
# 4                El Vino London Bridge
# ...                                ...
# 15115                 The Globe Tavern
# 15116             Quarter Bar & Lounge
# 15117                      The Mudlark
# 15118                       Anchor Tap
# 15119                          TwoRuba
#
#                                            venue_address        day  hour  \
# 0          8 Holyrood St, London SE1 2EL, United Kingdom   Saturday    14
# 1      26-27 Great Tower St, London EC3R 5AQ, United ...   Saturday     7
# 2      5a More London Pl, London SE1 2BY, United Kingdom    Tuesday    23
# 3      32 Borough High St, London SE1 1XU, United Kin...    Tuesday     6
# 4      5a More London Pl, London SE1 2BY, United Kingdom  Wednesday    15
# ...                                                  ...        ...   ...
# 15115        8 Bedale St, London SE1 9AL, United Kingdom   Thursday    22
# 15116  8-18 London Bridge St, London SE1 9SG, United ...     Friday    12
# 15117        Montague Cl, London SE1 9DA, United Kingdom  Wednesday     0
# 15118  20A Horselydown Ln, London SE1 2LN, United Kin...   Saturday     5
# 15119  5 More London Pl, Tooley St, London SE1 2BY, U...     Friday     0
#
#       busyness  busyness_numeric  popularity                     last_updated
# 0       Closed                 0    0.438710 2024-06-07 11:16:35.099076+00:00
# 1       Closed                 0    0.716129 2024-06-07 11:16:35.099076+00:00
# 2       Closed                 0    0.625806 2024-06-07 11:16:35.099076+00:00
# 3       Closed                 0    0.858065 2024-06-07 11:16:35.099076+00:00
# 4      Average                 3    0.625806 2024-06-07 11:16:35.099076+00:00
# ...        ...               ...         ...                              ...
# 15115  Average                 3    0.763314 2024-06-11 17:14:47.149651+00:00
# 15116  Average                 3    1.000000 2024-06-11 17:14:47.149651+00:00
# 15117   Closed                 0    0.627219 2024-06-11 17:14:47.149651+00:00
# 15118   Closed                 0    0.642012 2024-06-11 17:14:47.149651+00:00
# 15119  Average                 3    0.917160 2024-06-11 17:14:47.149651+00:00
#
# [15120 rows x 8 columns]

# %% [markdown]
# ### Step 4: Fetch Descriptions and Handle NaNs

# %%
def get_place_id(venue_name, api_key=GOOGLE_API_KEY):
    endpoint = 'https://maps.googleapis.com/maps/api/place/findplacefromtext/json'
    params = {
        'input': venue_name,
        'inputtype': 'textquery',
        'fields': 'place_id',
        'key': api_key
    }
    response = requests.get(endpoint, params=params)
    place_data = response.json()
    if place_data['candidates']:
        return place_data['candidates'][0]['place_id']
    return None

def get_place_details(place_id, api_key=GOOGLE_API_KEY):
    endpoint = f'https://places.googleapis.com/v1/places/{place_id}'
    headers = {
        'Content-Type': 'application/json',
        'X-Goog-Api-Key': api_key,
        'X-Goog-FieldMask': 'displayName,formattedAddress,editorialSummary,reviews'
    }
    response = requests.get(endpoint, headers=headers)
    return response.json()

def get_detailed_venues_info(venue_names):
    detailed_venues = []
    for name in venue_names:
        place_id = get_place_id(name)
        if place_id:
            details = get_place_details(place_id)
            if 'error' not in details:
                detailed_venues.append(details)
    return detailed_venues

venue_names = df['venue_name'].unique()
detailed_venues_info = get_detailed_venues_info(venue_names)

# Convert detailed venue info to DataFrame
detailed_venues_df = pd.DataFrame(detailed_venues_info)
detailed_venues_df = detailed_venues_df.dropna(subset=['displayName', 'editorialSummary', 'reviews'])

# Print the cleaned DataFrame to debug
print(detailed_venues_df)
# Out:
#                                      formattedAddress  \
# 0                   8 Holyrood St, London SE1 2EL, UK
# 1           26-27 Great Tower St, London EC3R 5AQ, UK
# 2               5a More London Pl, London SE1 2BY, UK
# 3              32 Borough High St, London SE1 1XU, UK
# 4         206-208 Tower Bridge Rd, London SE1 2LL, UK
# 6                      4 Hay's Ln, London SE1 2HB, UK
# 7                  1 Duke St Hill, London SE1 2SW, UK
# 8                 61 Royal Mint St, London E1 8LG, UK
# 9              75 Borough High St, London SE1 1NH, UK
# 11               10 Bermondsey St, London SE1 2ER, UK
# 12                    Montague Cl, London SE1 9DA, UK
# 13  Arch, 35B, 85B Southwark Bridge Rd, London SE1...
# 14  Greater, Unit 26, Hay’s Galleria, London SE1 2...
# 15             10-20 Redcross Way, London SE1 1TA, UK
# 16                 2, 4 Tooley St, London SE1 2SY, UK
# 18          8-18 London Bridge St, London SE1 9SG, UK
# 21               King's Head Yard, London SE1 1NA, UK
# 22                  186 Tooley St, London SE1 2TZ, UK
# 23                    111 Long Ln, London SE1 4PH, UK
# 24              2 Green Dragon Ct, London SE1 9AW, UK
# 25         14 Byward St, Greater, London EC3R 5BA, UK
# 27          171-173 Bermondsey St, London SE1 3UW, UK
# 29                    9 Stoney St, London SE1 9AA, UK
# 30                  1-3 Tooley St, London SE1 2PF, UK
# 31                    8 Bedale St, London SE1 9AL, UK
# 32               98 Bermondsey St, London SE1 3UB, UK
# 33  Butlers Wharf, 34 Shad Thames, Greater, London...
#
#                                           displayName  \
# 0        {'text': 'Nine Lives', 'languageCode': 'en'}
# 1   {'text': 'The Hung Drawn & Quartered, EC3', 'l...
# 2   {'text': 'El Vino London Bridge', 'languageCod...
# 3   {'text': 'The Bridge Tap, London', 'languageCo...
# 4   {'text': 'Tower Bridge Arms', 'languageCode': ...
# 6   {'text': 'Vivat Bacchus London Bridge', 'langu...
# 7     {'text': 'N1 Bar London', 'languageCode': 'en'}
# 8   {'text': 'Simmons Bar | Tower Bridge', 'langua...
# 9            {'text': 'George', 'languageCode': 'en'}
# 11  {'text': 'Electric Shuffle London Bridge', 'la...
# 12      {'text': 'The Mudlark', 'languageCode': 'en'}
# 13  {'text': 'Bar Douro London Bridge', 'languageC...
# 14  {'text': 'The Horniman at Hays', 'languageCode...
# 15  {'text': 'The Boot & Flogger', 'languageCode':...
# 16  {'text': 'Bermondsey Bierkeller', 'languageCod...
# 18  {'text': 'Quarter Bar & Lounge', 'languageCode...
# 21  {'text': 'The Old Kings Head', 'languageCode':...
# 22  {'text': 'The Two Bridges Ale House & Kitchen'...
# 23  {'text': 'The Old School Yard', 'languageCode'...
# 24   {'text': 'Whiskey Ginger', 'languageCode': 'en'}
# 25  {'text': 'All Bar One Tower Of London', 'langu...
# 27  {'text': 'The Last Talisman', 'languageCode': ...
# 29  {'text': 'The Market Porter', 'languageCode': ...
# 30        {'text': 'Mug House', 'languageCode': 'en'}
# 31  {'text': 'The Globe Tavern', 'languageCode': '...
# 32     {'text': 'The Woolpack', 'languageCode': 'en'}
# 33  {'text': 'All Bar One Butlers Wharf', 'languag...
#
#                                      editorialSummary  \
# 0   {'text': 'Modern house cocktails & craft beer ...
# 1   {'text': 'Stately city pub with chandeliers, m...
# 2   {'text': 'British and Mediterranean dishes ser...
# 3   {'text': 'Comfort foods such as pizza & burger...
# 4   {'text': 'A craft beer pub focused on both dra...
# 6   {'text': 'Premium cheese & fine wines, plus a ...
# 7   {'text': 'Late-opening sports bar with a big s...
# 8   {'text': 'Cocktail bar decked out with tiled w...
# 9   {'text': 'Authentic 17th-century coaching inn ...
# 11  {'text': 'Retro-style, brick-walled venue offe...
# 12  {'text': 'Open-plan pub with wooden beams and ...
# 13  {'text': 'Traditional Portuguese sharing plate...
# 14  {'text': 'Pub in former tea warehouse with the...
# 15  {'text': 'Long-standing bar with an elegant wo...
# 16  {'text': 'Chill bar with a game room serving w...
# 18  {'text': 'Airy, relaxed hotel bar, offering sn...
# 21  {'text': 'Conventional local pub with bar menu...
# 22  {'text': 'Warm, modern venue featuring classic...
# 23  {'text': 'School-themed cocktail party bar wit...
# 24  {'text': 'Cocktail bar with a trendy vibe, off...
# 25  {'text': 'Modern chain bar serving beer, cockt...
# 27  {'text': 'Cool bar serving up creative cocktai...
# 29  {'text': 'Traditional alehouse next to Borough...
# 30  {'text': 'Rustic, traditional pub for British ...
# 31  {'text': 'Traditional pub serving guest cask a...
# 32  {'text': 'Quirky bar with ornate tiling and ce...
# 33  {'text': 'Modern chain bar serving beer, cockt...
#
#                                               reviews
# 0   [{'name': 'places/ChIJ9eFJS0UDdkgRCBXBkYpfijM/...
# 1   [{'name': 'places/ChIJMzQ-Ck4DdkgRMwMt3XbK8MM/...
# 2   [{'name': 'places/ChIJZ22ADFADdkgRbg3EVKrgJqI/...
# 3   [{'name': 'places/ChIJ7fWU9kQDdkgRiYZnhbYMLqc/...
# 4   [{'name': 'places/ChIJG0yqxEUDdkgR1_OPMkw-0xk/...
# 6   [{'name': 'places/ChIJE2UVR1ADdkgRpLsNqbB0-r4/...
# 7   [{'name': 'places/ChIJFRrrxlADdkgRwc6JoZBMWus/...
# 8   [{'name': 'places/ChIJU2RB6TUDdkgRdMFTLtY_DYU/...
# 9   [{'name': 'places/ChIJo15e1lkDdkgR-X84Yf2cA0s/...
# 11  [{'name': 'places/ChIJbZiUoxsDdkgRG3fO4CTaBvA/...
# 12  [{'name': 'places/ChIJf6kWPFcDdkgRCUFAvvhk8fs/...
# 13  [{'name': 'places/ChIJG_1s4KcEdkgRz25CNiaeUkw/...
# 14  [{'name': 'places/ChIJzTKWP1ADdkgRTNDLN_08UDk/...
# 15  [{'name': 'places/ChIJibA5AVgDdkgR5rznzwbEHjk/...
# 16  [{'name': 'places/ChIJNSgQ7YEDdkgRbN-sTH_nEXE/...
# 18  [{'name': 'places/ChIJRz2mTVcDdkgRUd49u7Np6DY/...
# 21  [{'name': 'places/ChIJa2c6YVcDdkgRYAgQ0sCusN0/...
# 22  [{'name': 'places/ChIJ-y-NdEUDdkgRf-pX6Ox8kAM/...
# 23  [{'name': 'places/ChIJWRzJ4VsDdkgRMHSiUrObgpM/...
# 24  [{'name': 'places/ChIJcfK0a1cDdkgR42Y1Lb6Ycx0/...
# 25  [{'name': 'places/ChIJhyEUKkwDdkgR3o22dWfAq9o/...
# 27  [{'name': 'places/ChIJVTMjUWoDdkgR-7xUKfR2HdE/...
# 29  [{'name': 'places/ChIJWUFrnFcDdkgRTdLG4stiEqY/...
# 30  [{'name': 'places/ChIJHXBaLVcDdkgRkRwXzazF0ag/...
# 31  [{'name': 'places/ChIJ9_9YblcDdkgRoLJdCksgSdg/...
# 32  [{'name': 'places/ChIJiQegy0QDdkgRQ6n_kdh7Nik/...
# 33  [{'name': 'places/ChIJ4wQZyEcDdkgR61pd-XJO4z4/...

# %% [markdown]
# ### Step 5: Create Embeddings

# %%
def extract_description(row):
    details = row.to_dict()
    if isinstance(details, dict):
        if 'editorialSummary' in details and isinstance(details['editorialSummary'], dict) and 'text' in details['editorialSummary']:
            return details['editorialSummary']['text']
        elif 'reviews' in details and isinstance(details['reviews'], list) and len(details['reviews']) > 0 and isinstance(details['reviews'][0], dict) and 'text' in details['reviews'][0] and isinstance(details['reviews'][0]['text'], dict) and 'text' in details['reviews'][0]['text']:
            return details['reviews'][0]['text']['text']
        elif 'displayName' in details and isinstance(details['displayName'], dict) and 'text' in details['displayName']:
            return details['displayName']['text']
    return 'No description available'

# Apply the extraction function
detailed_venues_df['description'] = detailed_venues_df.apply(extract_description, axis=1)

# Initialize the SentenceTransformer model
model = SentenceTransformer('all-MiniLM-L6-v2').to('cpu')

def create_embeddings(df, model):
    descriptions = df['description'].tolist()
    embeddings = model.encode(descriptions).tolist()
    df['embeddings'] = embeddings
    return df

# Create embeddings for the descriptions
detailed_venues_df = create_embeddings(detailed_venues_df, model)
print(detailed_venues_df)
# Out:
# 2024-06-12 13:54:49,681 INFO: Use pytorch device_name: mps
# 2024-06-12 13:54:49,683 INFO: Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# 2024-06-12 13:54:51,281 WARNING: DeprecationWarning: The `ipykernel.comm.Comm` class has been deprecated. Please use the `comm` module instead.For creating comms, use the function `from comm import create_comm`.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
#                                      formattedAddress  \
# 0                   8 Holyrood St, London SE1 2EL, UK
# 1           26-27 Great Tower St, London EC3R 5AQ, UK
# 2               5a More London Pl, London SE1 2BY, UK
# 3              32 Borough High St, London SE1 1XU, UK
# 4         206-208 Tower Bridge Rd, London SE1 2LL, UK
# 6                      4 Hay's Ln, London SE1 2HB, UK
# 7                  1 Duke St Hill, London SE1 2SW, UK
# 8                 61 Royal Mint St, London E1 8LG, UK
# 9              75 Borough High St, London SE1 1NH, UK
# 11               10 Bermondsey St, London SE1 2ER, UK
# 12                    Montague Cl, London SE1 9DA, UK
# 13  Arch, 35B, 85B Southwark Bridge Rd, London SE1...
# 14  Greater, Unit 26, Hay’s Galleria, London SE1 2...
# 15             10-20 Redcross Way, London SE1 1TA, UK
# 16                 2, 4 Tooley St, London SE1 2SY, UK
# 18          8-18 London Bridge St, London SE1 9SG, UK
# 21               King's Head Yard, London SE1 1NA, UK
# 22                  186 Tooley St, London SE1 2TZ, UK
# 23                    111 Long Ln, London SE1 4PH, UK
# 24              2 Green Dragon Ct, London SE1 9AW, UK
# 25         14 Byward St, Greater, London EC3R 5BA, UK
# 27          171-173 Bermondsey St, London SE1 3UW, UK
# 29                    9 Stoney St, London SE1 9AA, UK
# 30                  1-3 Tooley St, London SE1 2PF, UK
# 31                    8 Bedale St, London SE1 9AL, UK
# 32               98 Bermondsey St, London SE1 3UB, UK
# 33  Butlers Wharf, 34 Shad Thames, Greater, London...
#
#                                           displayName  \
# 0        {'text': 'Nine Lives', 'languageCode': 'en'}
# 1   {'text': 'The Hung Drawn & Quartered, EC3', 'l...
# 2   {'text': 'El Vino London Bridge', 'languageCod...
# 3   {'text': 'The Bridge Tap, London', 'languageCo...
# 4   {'text': 'Tower Bridge Arms', 'languageCode': ...
# 6   {'text': 'Vivat Bacchus London Bridge', 'langu...
# 7     {'text': 'N1 Bar London', 'languageCode': 'en'}
# 8   {'text': 'Simmons Bar | Tower Bridge', 'langua...
# 9            {'text': 'George', 'languageCode': 'en'}
# 11  {'text': 'Electric Shuffle London Bridge', 'la...
# 12      {'text': 'The Mudlark', 'languageCode': 'en'}
# 13  {'text': 'Bar Douro London Bridge', 'languageC...
# 14  {'text': 'The Horniman at Hays', 'languageCode...
# 15  {'text': 'The Boot & Flogger', 'languageCode':...
# 16  {'text': 'Bermondsey Bierkeller', 'languageCod...
# 18  {'text': 'Quarter Bar & Lounge', 'languageCode...
# 21  {'text': 'The Old Kings Head', 'languageCode':...
# 22  {'text': 'The Two Bridges Ale House & Kitchen'...
# 23  {'text': 'The Old School Yard', 'languageCode'...
# 24   {'text': 'Whiskey Ginger', 'languageCode': 'en'}
# 25  {'text': 'All Bar One Tower Of London', 'langu...
# 27  {'text': 'The Last Talisman', 'languageCode': ...
# 29  {'text': 'The Market Porter', 'languageCode': ...
# 30        {'text': 'Mug House', 'languageCode': 'en'}
# 31  {'text': 'The Globe Tavern', 'languageCode': '...
# 32     {'text': 'The Woolpack', 'languageCode': 'en'}
# 33  {'text': 'All Bar One Butlers Wharf', 'languag...
#
#                                      editorialSummary  \
# 0   {'text': 'Modern house cocktails & craft beer ...
# 1   {'text': 'Stately city pub with chandeliers, m...
# 2   {'text': 'British and Mediterranean dishes ser...
# 3   {'text': 'Comfort foods such as pizza & burger...
# 4   {'text': 'A craft beer pub focused on both dra...
# 6   {'text': 'Premium cheese & fine wines, plus a ...
# 7   {'text': 'Late-opening sports bar with a big s...
# 8   {'text': 'Cocktail bar decked out with tiled w...
# 9   {'text': 'Authentic 17th-century coaching inn ...
# 11  {'text': 'Retro-style, brick-walled venue offe...
# 12  {'text': 'Open-plan pub with wooden beams and ...
# 13  {'text': 'Traditional Portuguese sharing plate...
# 14  {'text': 'Pub in former tea warehouse with the...
# 15  {'text': 'Long-standing bar with an elegant wo...
# 16  {'text': 'Chill bar with a game room serving w...
# 18  {'text': 'Airy, relaxed hotel bar, offering sn...
# 21  {'text': 'Conventional local pub with bar menu...
# 22  {'text': 'Warm, modern venue featuring classic...
# 23  {'text': 'School-themed cocktail party bar wit...
# 24  {'text': 'Cocktail bar with a trendy vibe, off...
# 25  {'text': 'Modern chain bar serving beer, cockt...
# 27  {'text': 'Cool bar serving up creative cocktai...
# 29  {'text': 'Traditional alehouse next to Borough...
# 30  {'text': 'Rustic, traditional pub for British ...
# 31  {'text': 'Traditional pub serving guest cask a...
# 32  {'text': 'Quirky bar with ornate tiling and ce...
# 33  {'text': 'Modern chain bar serving beer, cockt...
#
#                                               reviews  \
# 0   [{'name': 'places/ChIJ9eFJS0UDdkgRCBXBkYpfijM/...
# 1   [{'name': 'places/ChIJMzQ-Ck4DdkgRMwMt3XbK8MM/...
# 2   [{'name': 'places/ChIJZ22ADFADdkgRbg3EVKrgJqI/...
# 3   [{'name': 'places/ChIJ7fWU9kQDdkgRiYZnhbYMLqc/...
# 4   [{'name': 'places/ChIJG0yqxEUDdkgR1_OPMkw-0xk/...
# 6   [{'name': 'places/ChIJE2UVR1ADdkgRpLsNqbB0-r4/...
# 7   [{'name': 'places/ChIJFRrrxlADdkgRwc6JoZBMWus/...
# 8   [{'name': 'places/ChIJU2RB6TUDdkgRdMFTLtY_DYU/...
# 9   [{'name': 'places/ChIJo15e1lkDdkgR-X84Yf2cA0s/...
# 11  [{'name': 'places/ChIJbZiUoxsDdkgRG3fO4CTaBvA/...
# 12  [{'name': 'places/ChIJf6kWPFcDdkgRCUFAvvhk8fs/...
# 13  [{'name': 'places/ChIJG_1s4KcEdkgRz25CNiaeUkw/...
# 14  [{'name': 'places/ChIJzTKWP1ADdkgRTNDLN_08UDk/...
# 15  [{'name': 'places/ChIJibA5AVgDdkgR5rznzwbEHjk/...
# 16  [{'name': 'places/ChIJNSgQ7YEDdkgRbN-sTH_nEXE/...
# 18  [{'name': 'places/ChIJRz2mTVcDdkgRUd49u7Np6DY/...
# 21  [{'name': 'places/ChIJa2c6YVcDdkgRYAgQ0sCusN0/...
# 22  [{'name': 'places/ChIJ-y-NdEUDdkgRf-pX6Ox8kAM/...
# 23  [{'name': 'places/ChIJWRzJ4VsDdkgRMHSiUrObgpM/...
# 24  [{'name': 'places/ChIJcfK0a1cDdkgR42Y1Lb6Ycx0/...
# 25  [{'name': 'places/ChIJhyEUKkwDdkgR3o22dWfAq9o/...
# 27  [{'name': 'places/ChIJVTMjUWoDdkgR-7xUKfR2HdE/...
# 29  [{'name': 'places/ChIJWUFrnFcDdkgRTdLG4stiEqY/...
# 30  [{'name': 'places/ChIJHXBaLVcDdkgRkRwXzazF0ag/...
# 31  [{'name': 'places/ChIJ9_9YblcDdkgRoLJdCksgSdg/...
# 32  [{'name': 'places/ChIJiQegy0QDdkgRQ6n_kdh7Nik/...
# 33  [{'name': 'places/ChIJ4wQZyEcDdkgR61pd-XJO4z4/...
#
#                                           description  \
# 0   Modern house cocktails & craft beer poured in ...
# 1   Stately city pub with chandeliers, marble colu...
# 2   British and Mediterranean dishes served in a g...
# 3   Comfort foods such as pizza & burgers in a roo...
# 4   A craft beer pub focused on both draft and bot...
# 6   Premium cheese & fine wines, plus a seasonal m...
# 7   Late-opening sports bar with a big screen, tab...
# 8   Cocktail bar decked out with tiled walls and r...
# 9   Authentic 17th-century coaching inn and pub wi...
# 11  Retro-style, brick-walled venue offering shuff...
# 12  Open-plan pub with wooden beams and outdoor se...
# 13  Traditional Portuguese sharing plates and inte...
# 14  Pub in former tea warehouse with thematic frie...
# 15  Long-standing bar with an elegant wood-panelle...
# 16  Chill bar with a game room serving wings, burg...
# 18  Airy, relaxed hotel bar, offering snacks and s...
# 21  Conventional local pub with bar menu and upsta...
# 22  Warm, modern venue featuring classic pub meals...
# 23  School-themed cocktail party bar with retro ar...
# 24  Cocktail bar with a trendy vibe, offering burg...
# 25  Modern chain bar serving beer, cocktails, wine...
# 27  Cool bar serving up creative cocktails & a men...
# 29  Traditional alehouse next to Borough Market wi...
# 30  Rustic, traditional pub for British cheese pla...
# 31  Traditional pub serving guest cask ales & craf...
# 32  Quirky bar with ornate tiling and ceiling, off...
# 33  Modern chain bar serving beer, cocktails, wine...
#
#                                            embeddings
# 0   [0.054957516491413116, -0.003484186017885804, ...
# 1   [0.1009427085518837, 0.036972153931856155, -0....
# 2   [-0.018644321709871292, -0.04129507765173912, ...
# 3   [-0.011864970438182354, 0.021110650151968002, ...
# 4   [-0.019743412733078003, 0.012091589160263538, ...
# 6   [-0.03046800196170807, -0.005981300491839647, ...
# 7   [0.041939929127693176, 0.0036718114279210567, ...
# 8   [0.01178203895688057, 0.032252006232738495, 0....
# 9   [0.06979238241910934, 0.031619779765605927, -0...
# 11  [0.005012433975934982, 0.07066862285137177, -0...
# 12  [0.07960762828588486, -0.00031194687471725047,...
# 13  [0.003156776772812009, 0.015444889664649963, -...
# 14  [0.12037107348442078, -0.05562582239508629, -0...
# 15  [0.017139727249741554, 0.015469740144908428, -...
# 16  [-0.03657763823866844, 0.009011972695589066, -...
# 18  [-0.0366564504802227, 0.014483081176877022, 0....
# 21  [0.11079748719930649, -0.009339046664536, -0.0...
# 22  [0.10094434767961502, 0.03158826753497124, -0....
# 23  [-0.021689774468541145, 0.04437754303216934, 0...
# 24  [-0.032649144530296326, -0.021302198991179466,...
# 25  [-0.025669118389487267, 0.02020202949643135, -...
# 27  [-0.05787510797381401, 0.0027325539849698544, ...
# 29  [0.14619728922843933, 0.00969020277261734, -0....
# 30  [0.07054409384727478, -0.04031555727124214, -0...
# 31  [0.10030007362365723, 0.02989223413169384, -0....
# 32  [0.01386584248393774, 0.024043332785367966, 0....
# 33  [-0.02566910907626152, 0.020202023908495903, -...

# %% [markdown]
# ### Step 6: Insert Data into Feature Group

# %%
# Add an 'id' column as the primary key
detailed_venues_df['id'] = detailed_venues_df.index

def get_or_create_description_feature_group():
    try:
        fg = fs.get_feature_group(name=FEATURE_GROUP_EMBEDDING_NAME, version=FEATURE_GROUP_EMBEDDING_VERSION)
    except:
        fg = fs.create_feature_group(
            name=FEATURE_GROUP_EMBEDDING_NAME,
            version=FEATURE_GROUP_EMBEDDING_VERSION,
            description="Embeddings for venue descriptions",
            primary_key=['id'],
            online_enabled=True
        )
    return fg

description_feature_group = get_or_create_description_feature_group()

# Insert data into the feature group
description_feature_group.insert(detailed_venues_df)

# Read back the feature group to ensure data insertion
feature_group_desc = get_or_create_description_feature_group()
df_desc = feature_group_desc.read()

print(df_desc)
# Out:
# Uploading Dataframe: 0.00% |          | Rows 0/27 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: venue_description_embeddings_2_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/25749/jobs/named/venue_description_embeddings_2_offline_fg_materialization/executions
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (0.94s)
#                                      formattedaddress  \
# 0           26-27 Great Tower St, London EC3R 5AQ, UK
# 1                King's Head Yard, London SE1 1NA, UK
# 2                   1-3 Tooley St, London SE1 2PF, UK
# 3                     Montague Cl, London SE1 9DA, UK
# 4                      4 Hay's Ln, London SE1 2HB, UK
# 5           8-18 London Bridge St, London SE1 9SG, UK
# 6                  1 Duke St Hill, London SE1 2SW, UK
# 7               5a More London Pl, London SE1 2BY, UK
# 8                     8 Bedale St, London SE1 9AL, UK
# 9           171-173 Bermondsey St, London SE1 3UW, UK
# 10  Arch, 35B, 85B Southwark Bridge Rd, London SE1...
# 11                  186 Tooley St, London SE1 2TZ, UK
# 12  Greater, Unit 26, Hay’s Galleria, London SE1 2...
# 13             32 Borough High St, London SE1 1XU, UK
# 14                61 Royal Mint St, London E1 8LG, UK
# 15               98 Bermondsey St, London SE1 3UB, UK
# 16                    111 Long Ln, London SE1 4PH, UK
# 17              2 Green Dragon Ct, London SE1 9AW, UK
# 18                    9 Stoney St, London SE1 9AA, UK
# 19        206-208 Tower Bridge Rd, London SE1 2LL, UK
# 20             75 Borough High St, London SE1 1NH, UK
# 21             10-20 Redcross Way, London SE1 1TA, UK
# 22  Butlers Wharf, 34 Shad Thames, Greater, London...
# 23                  8 Holyrood St, London SE1 2EL, UK
# 24                 2, 4 Tooley St, London SE1 2SY, UK
# 25               10 Bermondsey St, London SE1 2ER, UK
# 26         14 Byward St, Greater, London EC3R 5BA, UK
#
#                                           displayname  \
# 0   {'languagecode': None, 'text': 'The Hung Drawn...
# 1   {'languagecode': None, 'text': 'The Old Kings ...
# 2         {'languagecode': None, 'text': 'Mug House'}
# 3       {'languagecode': None, 'text': 'The Mudlark'}
# 4   {'languagecode': None, 'text': 'Vivat Bacchus ...
# 5   {'languagecode': None, 'text': 'Quarter Bar & ...
# 6     {'languagecode': None, 'text': 'N1 Bar London'}
# 7   {'languagecode': None, 'text': 'El Vino London...
# 8   {'languagecode': None, 'text': 'The Globe Tave...
# 9   {'languagecode': None, 'text': 'The Last Talis...
# 10  {'languagecode': None, 'text': 'Bar Douro Lond...
# 11  {'languagecode': None, 'text': 'The Two Bridge...
# 12  {'languagecode': None, 'text': 'The Horniman a...
# 13  {'languagecode': None, 'text': 'The Bridge Tap...
# 14  {'languagecode': None, 'text': 'Simmons Bar | ...
# 15     {'languagecode': None, 'text': 'The Woolpack'}
# 16  {'languagecode': None, 'text': 'The Old School...
# 17   {'languagecode': None, 'text': 'Whiskey Ginger'}
# 18  {'languagecode': None, 'text': 'The Market Por...
# 19  {'languagecode': None, 'text': 'Tower Bridge A...
# 20           {'languagecode': None, 'text': 'George'}
# 21  {'languagecode': None, 'text': 'The Boot & Flo...
# 22  {'languagecode': None, 'text': 'All Bar One Bu...
# 23       {'languagecode': None, 'text': 'Nine Lives'}
# 24  {'languagecode': None, 'text': 'Bermondsey Bie...
# 25  {'languagecode': None, 'text': 'Electric Shuff...
# 26  {'languagecode': None, 'text': 'All Bar One To...
#
#                                      editorialsummary  \
# 0   {'languagecode': None, 'text': 'Stately city p...
# 1   {'languagecode': None, 'text': 'Conventional l...
# 2   {'languagecode': None, 'text': 'Rustic, tradit...
# 3   {'languagecode': None, 'text': 'Open-plan pub ...
# 4   {'languagecode': None, 'text': 'Premium cheese...
# 5   {'languagecode': None, 'text': 'Airy, relaxed ...
# 6   {'languagecode': None, 'text': 'Late-opening s...
# 7   {'languagecode': None, 'text': 'British and Me...
# 8   {'languagecode': None, 'text': 'Traditional pu...
# 9   {'languagecode': None, 'text': 'Cool bar servi...
# 10  {'languagecode': None, 'text': 'Traditional Po...
# 11  {'languagecode': None, 'text': 'Warm, modern v...
# 12  {'languagecode': None, 'text': 'Pub in former ...
# 13  {'languagecode': None, 'text': 'Comfort foods ...
# 14  {'languagecode': None, 'text': 'Cocktail bar d...
# 15  {'languagecode': None, 'text': 'Quirky bar wit...
# 16  {'languagecode': None, 'text': 'School-themed ...
# 17  {'languagecode': None, 'text': 'Cocktail bar w...
# 18  {'languagecode': None, 'text': 'Traditional al...
# 19  {'languagecode': None, 'text': 'A craft beer p...
# 20  {'languagecode': None, 'text': 'Authentic 17th...
# 21  {'languagecode': None, 'text': 'Long-standing ...
# 22  {'languagecode': None, 'text': 'Modern chain b...
# 23  {'languagecode': None, 'text': 'Modern house c...
# 24  {'languagecode': None, 'text': 'Chill bar with...
# 25  {'languagecode': None, 'text': 'Retro-style, b...
# 26  {'languagecode': None, 'text': 'Modern chain b...
#
#                                               reviews  \
# 0   [{'authorattribution': None, 'name': 'places/C...
# 1   [{'authorattribution': None, 'name': 'places/C...
# 2   [{'authorattribution': None, 'name': 'places/C...
# 3   [{'authorattribution': None, 'name': 'places/C...
# 4   [{'authorattribution': None, 'name': 'places/C...
# 5   [{'authorattribution': None, 'name': 'places/C...
# 6   [{'authorattribution': None, 'name': 'places/C...
# 7   [{'authorattribution': None, 'name': 'places/C...
# 8   [{'authorattribution': None, 'name': 'places/C...
# 9   [{'authorattribution': None, 'name': 'places/C...
# 10  [{'authorattribution': None, 'name': 'places/C...
# 11  [{'authorattribution': None, 'name': 'places/C...
# 12  [{'authorattribution': None, 'name': 'places/C...
# 13  [{'authorattribution': None, 'name': 'places/C...
# 14  [{'authorattribution': None, 'name': 'places/C...
# 15  [{'authorattribution': None, 'name': 'places/C...
# 16  [{'authorattribution': None, 'name': 'places/C...
# 17  [{'authorattribution': None, 'name': 'places/C...
# 18  [{'authorattribution': None, 'name': 'places/C...
# 19  [{'authorattribution': None, 'name': 'places/C...
# 20  [{'authorattribution': None, 'name': 'places/C...
# 21  [{'authorattribution': None, 'name': 'places/C...
# 22  [{'authorattribution': None, 'name': 'places/C...
# 23  [{'authorattribution': None, 'name': 'places/C...
# 24  [{'authorattribution': None, 'name': 'places/C...
# 25  [{'authorattribution': None, 'name': 'places/C...
# 26  [{'authorattribution': None, 'name': 'places/C...
#
#                                           description  \
# 0   Stately city pub with chandeliers, marble colu...
# 1   Conventional local pub with bar menu and upsta...
# 2   Rustic, traditional pub for British cheese pla...
# 3   Open-plan pub with wooden beams and outdoor se...
# 4   Premium cheese & fine wines, plus a seasonal m...
# 5   Airy, relaxed hotel bar, offering snacks and s...
# 6   Late-opening sports bar with a big screen, tab...
# 7   British and Mediterranean dishes served in a g...
# 8   Traditional pub serving guest cask ales & craf...
# 9   Cool bar serving up creative cocktails & a men...
# 10  Traditional Portuguese sharing plates and inte...
# 11  Warm, modern venue featuring classic pub meals...
# 12  Pub in former tea warehouse with thematic frie...
# 13  Comfort foods such as pizza & burgers in a roo...
# 14  Cocktail bar decked out with tiled walls and r...
# 15  Quirky bar with ornate tiling and ceiling, off...
# 16  School-themed cocktail party bar with retro ar...
# 17  Cocktail bar with a trendy vibe, offering burg...
# 18  Traditional alehouse next to Borough Market wi...
# 19  A craft beer pub focused on both draft and bot...
# 20  Authentic 17th-century coaching inn and pub wi...
# 21  Long-standing bar with an elegant wood-panelle...
# 22  Modern chain bar serving beer, cocktails, wine...
# 23  Modern house cocktails & craft beer poured in ...
# 24  Chill bar with a game room serving wings, burg...
# 25  Retro-style, brick-walled venue offering shuff...
# 26  Modern chain bar serving beer, cocktails, wine...
#
#                                            embeddings  id
# 0   [0.1009427085518837, 0.036972153931856155, -0....   1
# 1   [0.11079748719930649, -0.009339046664536, -0.0...  21
# 2   [0.07054409384727478, -0.04031555727124214, -0...  30
# 3   [0.07960762828588486, -0.00031194687471725047,...  12
# 4   [-0.03046800196170807, -0.005981300491839647, ...   6
# 5   [-0.0366564504802227, 0.014483081176877022, 0....  18
# 6   [0.041939929127693176, 0.0036718114279210567, ...   7
# 7   [-0.018644321709871292, -0.04129507765173912, ...   2
# 8   [0.10030007362365723, 0.02989223413169384, -0....  31
# 9   [-0.05787510797381401, 0.0027325539849698544, ...  27
# 10  [0.003156776772812009, 0.015444889664649963, -...  13
# 11  [0.10094434767961502, 0.03158826753497124, -0....  22
# 12  [0.12037107348442078, -0.05562582239508629, -0...  14
# 13  [-0.011864970438182354, 0.021110650151968002, ...   3
# 14  [0.01178203895688057, 0.032252006232738495, 0....   8
# 15  [0.01386584248393774, 0.024043332785367966, 0....  32
# 16  [-0.021689774468541145, 0.04437754303216934, 0...  23
# 17  [-0.032649144530296326, -0.021302198991179466,...  24
# 18  [0.14619728922843933, 0.00969020277261734, -0....  29
# 19  [-0.019743412733078003, 0.012091589160263538, ...   4
# 20  [0.06979238241910934, 0.031619779765605927, -0...   9
# 21  [0.017139727249741554, 0.015469740144908428, -...  15
# 22  [-0.02566910907626152, 0.020202023908495903, -...  33
# 23  [0.054957516491413116, -0.003484186017885804, ...   0
# 24  [-0.03657763823866844, 0.009011972695589066, -...  16
# 25  [0.005012433975934982, 0.07066862285137177, -0...  11
# 26  [-0.025669118389487267, 0.02020202949643135, -...  25
